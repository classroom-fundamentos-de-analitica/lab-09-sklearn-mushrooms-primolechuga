# %%
import pandas as pd

train_dataset = pd.read_csv('train_dataset.csv')
test_dataset = pd.read_csv('test_dataset.csv')

train_dataset.head()
# Out:
# C:\Users\juane\AppData\Local\Temp\ipykernel_19408\4284657527.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           y         n       t    p               f
# 1    e         f           y         g       t    n               f
# 2    e         x           y         y       t    a               f
# 3    e         x           s         w       f    n               f
# 4    e         x           f         n       t    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          p  ...                        s
# 1            c         b          p  ...                        s
# 2            c         b          k  ...                        s
# 3            w         b          k  ...                        s
# 4            c         b          p  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      g                      g         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      p                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 k          y       d
# 2           o         p                 n          n       m
# 3           o         e                 k          a       g
# 4           o         p                 n          v       d
#
# [5 rows x 23 columns]

# %%
train_dataset.isna().sum()
# Out:
# type                        0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
train_dataset.describe()
# Out:
#         type cap_shape cap_surface cap_color bruises  odor gill_attachment  \
# count   6093      6093        6093      6093    6093  6093            6093
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    3167      2740        2449      1721    3562  2627            5935
#
#        gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# count          6093      6093       6093  ...                     6093
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           5112      4221       1302  ...                     3719
#
#        stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# count                    6093                   6093      6093       6093
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     3346                   3277      6093       5944
#
#        ring_number ring_type spore_print_color population habitat
# count         6093      6093              6093       6093    6093
# unique           3         5                 9          6       7
# top              o         p                 w          v       d
# freq          5628      2965              1778       3048    2361
#
# [4 rows x 23 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
enconder = OneHotEncoder()
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('type')
test_labels = test_features.pop('type')

train_features = enconder.fit_transform(train_features)
test_features = enconder.transform(test_features)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(train_features, train_labels)
preds = model.predict(test_features)

accuracy = accuracy_score(test_labels, preds)
print(f'Model Accuracy: {accuracy}')
# Out:
# Model Accuracy: 1.0

# %%
import pickle

with open('model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

with open('model.pkl', 'rb') as model_file:
    model = pickle.load(model_file)
